# %%
import pandas as pd
import xml.etree.ElementTree as ET
import re
import shutil
import os
from lxml import etree
def remove_namespace(tree):
    for elem in tree.iter():
        if '}' in elem.tag:
            elem.tag = elem.tag.split('}', 1)[1]

def fix_xml_content(content):
    parser = etree.XMLParser(recover=True)
    root = etree.fromstring(content, parser=parser)
    return etree.tostring(root, encoding='unicode')

def modify_dxl_file(input_file, output_file):
    with open(input_file, 'r', encoding='utf-8') as file:
        dxl_content = file.read()
    dxl_content = re.sub(r'<field><field', '<field', dxl_content)
    dxl_content = re.sub(r'</field></field>', '</field>', dxl_content)
    with open(output_file, 'w', encoding='utf-8') as file:
        file.write(dxl_content)
    print("DXL 文件已成功修改。")

def extract_data(elements, element_name, attrib_name):
    global keyword
    pattern_formula = r"<formula>(.*?)</formula>"
    pattern_lotus = r"<lotusscript>(.*?)</lotusscript>"
    button_name_f = r"/>(.*?)</button>"
    button_name_lo = r"/>(.*?)<code"
    data_list = pd.DataFrame(columns=[attrib_name, 'Formula', 'Flag', 'Event'])

    default_data = pd.DataFrame([{attrib_name: 'N/A', 'Formula': 'N/A', 'Flag': 'N/A', 'Event': 'N/A'}])
    data_list = pd.concat([data_list, default_data], ignore_index=True)

    for elem in elements:
        elem_str = ET.tostring(elem, encoding='unicode')
        match_formula = re.search(pattern_formula, elem_str, re.DOTALL)
        match_lotus = re.search(pattern_lotus, elem_str, re.DOTALL)
        code_elem = elem.find(".//code")
        event_value = code_elem.attrib['event'] if code_elem is not None else "No event"

        if match_formula:
            content_formula = match_formula.group(1).strip()
        else:
            content_formula = "No formula"
        if match_lotus:
            content_lotus = match_lotus.group(1).strip()
        else:
            content_lotus = "No lotusscript"

        #flag = 'Y' if '"ns1"' in content_formula or '"ns1"' in content_lotus else 'N'
        flag = 'Y' if keyword in content_formula or keyword in content_lotus else 'N'
        if element_name == 'button':
            if content_formula == "No formula":
                match_button = re.search(button_name_lo, elem_str, re.DOTALL)
            elif content_lotus == "No lotusscript":
                match_button = re.search(button_name_f, elem_str, re.DOTALL)
            if match_button:
                attribs = elem.attrib
                attribs[attrib_name] = match_button.group(1).strip()
                attribs['Flag'] = flag
                attribs['Event'] = event_value
                attribs['Formula'] = content_formula
                attribs['LotusScript'] = content_lotus
                new_row = pd.DataFrame([attribs])
                data_list = pd.concat([data_list, new_row], ignore_index=True)
                continue
        attribs = elem.attrib
        attribs[attrib_name] = elem.attrib.get('name', elem.attrib.get('title', elem.attrib.get('htmlid', '')))
        attribs['Flag'] = flag
        attribs['Event'] = event_value
        attribs['Formula'] = content_formula
        attribs['LotusScript'] = content_lotus
        new_row = pd.DataFrame([attribs])
        data_list = pd.concat([data_list, new_row], ignore_index=True)

    return data_list

def process_dxl_file(input_file, output_file, is_agent_file, is_page_file):
    tree = ET.parse(input_file)
    root = tree.getroot()
    remove_namespace(root)

    if is_agent_file or is_page_file:
        code_elements = root.findall(".//code")
        code_list = extract_data(code_elements, 'code', 'CodeName')
        flag_column = code_list['Flag']
    else:
        field_list = extract_data(root.findall(".//field[@type]"), 'field', 'FieldName')
        action_list = extract_data(root.findall(".//action[@title]"), 'action', 'ActionTitle')
        actionhotspot_list = extract_data(root.findall(".//actionhotspot[@hotspotstyle]"), 'actionhotspot', 'ActionHotspotTitle')
        area_list = extract_data(root.findall(".//area[@type]"), 'area', '焦點資訊名稱')
        button_list = extract_data(root.findall(".//button"), 'button', 'ButtonName')
        flag_column = pd.concat([field_list['Flag'], action_list['Flag'],actionhotspot_list['Flag'], area_list['Flag'], button_list['Flag']])

    if 'Y' in flag_column.values:
        match = re.search(r'fixed_(.*?)_process\.dxl', input_file)
        extracted_filename = match.group(1)
        with open('result.txt', 'a', encoding='utf-8') as result_file:
            result_file.write(f"檔案 {extracted_filename} 包含 flag 為 'Y' 的欄位。\n")


    with pd.ExcelWriter(output_file) as writer:
        if is_agent_file or is_page_file:
            code_list.to_excel(writer, sheet_name='Code', index=False)
        else:
            field_list.to_excel(writer, sheet_name='Fields', index=False)
            action_list.to_excel(writer, sheet_name='Actions', index=False)
            actionhotspot_list.to_excel(writer, sheet_name='ActionHotspots', index=False)
            area_list.to_excel(writer, sheet_name='Area', index=False)
            button_list.to_excel(writer, sheet_name='Buttons', index=False)

    #tree.write('modified_' + input_file, encoding='unicode')
    #modify_dxl_file('modified_' + input_file, 'modified_' + input_file)

def process_dxl_files_in_directory(directory):
    for filename in os.listdir(directory):
        if filename.endswith('.dxl'):
            input_file = os.path.join(directory, filename)
            with open(input_file, 'r', encoding='big5', errors='ignore') as file:
                dxl_content = file.read()

            fixed_dxl_content = fix_xml_content(dxl_content)

            fixed_file = os.path.join(directory, 'fixed_' + filename)
            with open(fixed_file, 'w', encoding='utf-8') as file:
                file.write(fixed_dxl_content)

            # Copy the fixed DXL file to a new file with _process suffix
            process_file = fixed_file.replace('.dxl', '_process.dxl')
            shutil.copy(fixed_file, process_file)

            is_agent_file = "Agents" in filename or "ScriptLibraries" in filename
            is_page_file = "Pages" in filename

            # Process the copied DXL file
            output_file = os.path.join(directory, filename.replace('.dxl', '.xlsx'))
            process_dxl_file(process_file, output_file, is_agent_file, is_page_file)
            print(f"已處理 {filename}，輸出檔案為 {output_file}。")

def delete_fixed_files(directory):
    for filename in os.listdir(directory):
        if filename.startswith('fixed_'):
            file_path = os.path.join(directory, filename)
            try:
                os.remove(file_path)
                print(f"已刪除文件: {file_path}")
            except Exception as e:
                print(f"刪除文件失敗: {file_path}, 錯誤: {e}")


# Specify the directory containing the DXL files
keyword = input("請輸入要搜尋的關鍵字：")
with open('result.txt', 'w', encoding='utf-8') as result_file:
        result_file.write('')
directory = os.path.dirname(os.path.abspath(__file__))  #py用這個
#directory = os.getcwd()  #ipy用這個
process_dxl_files_in_directory(directory)
delete_fixed_files(directory)
print("所有 DXL 檔案已處理完成。")
# input_file = 'test.dxl'
# with open(input_file, 'r') as file:
#     dxl_content = file.read()

# fixed_dxl_content = fix_xml_content(dxl_content)

# fixed_file = 'fixed_' + input_file
# with open(fixed_file, 'w', encoding='utf-8') as file:
#     file.write(fixed_dxl_content)

# # Copy the fixed DXL file to a new file with _process suffix
# process_dxl_file('SubForms_($WFlowControl).dxl', 'output.xlsx')
# Out:
# 已處理 Agents_$自動核准.dxl，輸出檔案為 d:\dxl\膳食系統\Agents_$自動核准.xlsx。
# 已處理 Agents_$自動稽催.dxl，輸出檔案為 d:\dxl\膳食系統\Agents_$自動稽催.xlsx。
# 已處理 Agents_($CleanDelete).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_($CleanDelete).xlsx。
# 已處理 Agents_($CloseWindow).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_($CloseWindow).xlsx。
# 已處理 Agents_($CompleteM).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_($CompleteM).xlsx。
# 已處理 Agents_($CompleteN).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_($CompleteN).xlsx。
# 已處理 Agents_($CompleteN_ADD).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_($CompleteN_ADD).xlsx。
# 已處理 Agents_($CompleteW).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_($CompleteW).xlsx。
# 已處理 Agents_($Complete_ROS).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_($Complete_ROS).xlsx。
# 已處理 Agents_($CopyAttAgent).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_($CopyAttAgent).xlsx。
# 已處理 Agents_($DeleteDoc).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_($DeleteDoc).xlsx。
# 已處理 Agents_($FieldCheck).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_($FieldCheck).xlsx。
# 已處理 Agents_($ISAI_SendEx).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_($ISAI_SendEx).xlsx。
# 已處理 Agents_($ISAI_UpdateOutboxState).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_($ISAI_UpdateOutboxState).xlsx。
# 已處理 Agents_($Pre_WFlowApprStatus_ADD).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_($Pre_WFlowApprStatus_ADD).xlsx。
# 已處理 Agents_($SendMail).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_($SendMail).xlsx。
# 已處理 Agents_($UnDelete).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_($UnDelete).xlsx。
# 已處理 Agents_($WAgentTmpReaders).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_($WAgentTmpReaders).xlsx。
# 已處理 Agents_($WebQueryOpen).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_($WebQueryOpen).xlsx。
# 已處理 Agents_($WebQuerySave).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_($WebQuerySave).xlsx。
# 已處理 Agents_($WRemoveDoc).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_($WRemoveDoc).xlsx。
# 已處理 Agents_($建立文件).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_($建立文件).xlsx。
# 已處理 Agents_($手動停止簽核).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_($手動停止簽核).xlsx。
# 已處理 Agents_($手動核准).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_($手動核准).xlsx。
# 已處理 Agents_($手動稽催).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_($手動稽催).xlsx。
# 已處理 Agents_($指定簽核代理人).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_($指定簽核代理人).xlsx。
# 已處理 Agents_($檢視簽核狀態).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_($檢視簽核狀態).xlsx。
# 已處理 Agents_(CheckComPay).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(CheckComPay).xlsx。
# 已處理 Agents_(CheckField).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(CheckField).xlsx。
# 已處理 Agents_(CheckTodayFood).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(CheckTodayFood).xlsx。
# 已處理 Agents_(CheckTodayFood_20230406).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(CheckTodayFood_20230406).xlsx。
# 已處理 Agents_(Close).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(Close).xlsx。
# 已處理 Agents_(CreateExtraFood).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(CreateExtraFood).xlsx。
# 已處理 Agents_(Discount).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(Discount).xlsx。
# 已處理 Agents_(ExportDXL).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(ExportDXL).xlsx。
# 已處理 Agents_(F_ViewToCSV).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(F_ViewToCSV).xlsx。
# 已處理 Agents_(GetSerialNo).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(GetSerialNo).xlsx。
# 已處理 Agents_(I_ViewToCSV).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(I_ViewToCSV).xlsx。
# 已處理 Agents_(I_ViewToExcelByDate).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(I_ViewToExcelByDate).xlsx。
# 已處理 Agents_(Merge).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(Merge).xlsx。
# 已處理 Agents_(Merge_Af_ST1).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(Merge_Af_ST1).xlsx。
# 已處理 Agents_(ModifyFood).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(ModifyFood).xlsx。
# 已處理 Agents_(M_ViewToCSV).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(M_ViewToCSV).xlsx。
# 已處理 Agents_(M_ViewToExcelByDate).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(M_ViewToExcelByDate).xlsx。
# 已處理 Agents_(Notify).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(Notify).xlsx。
# 已處理 Agents_(NotifyApplictor).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(NotifyApplictor).xlsx。
# 已處理 Agents_(Open).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(Open).xlsx。
# 已處理 Agents_(PressF9).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(PressF9).xlsx。
# 已處理 Agents_(Q_ViewToCSV).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(Q_ViewToCSV).xlsx。
# 已處理 Agents_(Updatemylunch).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(Updatemylunch).xlsx。
# 已處理 Agents_(ViewToCSV).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(ViewToCSV).xlsx。
# 已處理 Agents_(ViewToCSV20071115).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(ViewToCSV20071115).xlsx。
# 已處理 Agents_(ViewToExcel).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(ViewToExcel).xlsx。
# 已處理 Agents_(ViewToExcelByAccount).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(ViewToExcelByAccount).xlsx。
# 已處理 Agents_(ViewToExcelByDate).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(ViewToExcelByDate).xlsx。
# 已處理 Agents_(備份：I_ViewToCSV).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(備份：I_ViewToCSV).xlsx。
# 已處理 Agents_(備份：M_ViewToCSV).dxl，輸出檔案為 d:\dxl\膳食系統\Agents_(備份：M_ViewToCSV).xlsx。
# 已處理 Agents_AutoSaveBySelect.dxl，輸出檔案為 d:\dxl\膳食系統\Agents_AutoSaveBySelect.xlsx。
# 已處理 Agents_ChangeArchive.dxl，輸出檔案為 d:\dxl\膳食系統\Agents_ChangeArchive.xlsx。
# 已處理 Agents_ImportFromExcel_Food.dxl，輸出檔案為 d:\dxl\膳食系統\Agents_ImportFromExcel_Food.xlsx。
# 已處理 Agents_lookupCompany.dxl，輸出檔案為 d:\dxl\膳食系統\Agents_lookupCompany.xlsx。
# 已處理 Agents_lookupEmpNo.dxl，輸出檔案為 d:\dxl\膳食系統\Agents_lookupEmpNo.xlsx。
# 已處理 Agents_RemoveFlag.dxl，輸出檔案為 d:\dxl\膳食系統\Agents_RemoveFlag.xlsx。
# 已處理 Agents_UpFlowStep.dxl，輸出檔案為 d:\dxl\膳食系統\Agents_UpFlowStep.xlsx。
# 已處理 Agents_Utility01. Set Fields.dxl，輸出檔案為 d:\dxl\膳食系統\Agents_Utility01. Set Fields.xlsx。
# 已處理 Agents_備份：$自動核准.dxl，輸出檔案為 d:\dxl\膳食系統\Agents_備份：$自動核准.xlsx。
# 已處理 Forms_($dlgboxUpFlowStep).dxl，輸出檔案為 d:\dxl\膳食系統\Forms_($dlgboxUpFlowStep).xlsx。
# 已處理 Forms_($dlgboxUpFlowStep_mail).dxl，輸出檔案為 d:\dxl\膳食系統\Forms_($dlgboxUpFlowStep_mail).xlsx。
# 已處理 Forms_($NameQueryToADD).dxl，輸出檔案為 d:\dxl\膳食系統\Forms_($NameQueryToADD).xlsx。
# 已處理 Forms_($NameQueryToCROSS).dxl，輸出檔案為 d:\dxl\膳食系統\Forms_($NameQueryToCROSS).xlsx。
# 已處理 Forms_($ODBCProfile).dxl，輸出檔案為 d:\dxl\膳食系統\Forms_($ODBCProfile).xlsx。
# 已處理 Forms_($Set Fields).dxl，輸出檔案為 d:\dxl\膳食系統\Forms_($Set Fields).xlsx。
# 已處理 Forms_($WFlowForm).dxl，輸出檔案為 d:\dxl\膳食系統\Forms_($WFlowForm).xlsx。
# 已處理 Forms_($WFlowSTSetup).dxl，輸出檔案為 d:\dxl\膳食系統\Forms_($WFlowSTSetup).xlsx。
# 已處理 Forms_($WNameQueryToADD).dxl，輸出檔案為 d:\dxl\膳食系統\Forms_($WNameQueryToADD).xlsx。
# 已處理 Forms_($WNameQueryToCROSS).dxl，輸出檔案為 d:\dxl\膳食系統\Forms_($WNameQueryToCROSS).xlsx。
# 已處理 Forms_($WProfile).dxl，輸出檔案為 d:\dxl\膳食系統\Forms_($WProfile).xlsx。
# 已處理 Forms_($WSysReaderSetting).dxl，輸出檔案為 d:\dxl\膳食系統\Forms_($WSysReaderSetting).xlsx。
# 已處理 Forms_($同名選擇).dxl，輸出檔案為 d:\dxl\膳食系統\Forms_($同名選擇).xlsx。
# 已處理 Forms_($指定簽核代理人).dxl，輸出檔案為 d:\dxl\膳食系統\Forms_($指定簽核代理人).xlsx。
# 已處理 Forms_($輸入意見).dxl，輸出檔案為 d:\dxl\膳食系統\Forms_($輸入意見).xlsx。
# 已處理 Forms_($輸入意見_預覽).dxl，輸出檔案為 d:\dxl\膳食系統\Forms_($輸入意見_預覽).xlsx。
# 已處理 Forms_(ModifyFoods).dxl，輸出檔案為 d:\dxl\膳食系統\Forms_(ModifyFoods).xlsx。
# 已處理 Forms_(NotifyApplictor).dxl，輸出檔案為 d:\dxl\膳食系統\Forms_(NotifyApplictor).xlsx。
# 已處理 Forms_Dialog_Menu圖片.dxl，輸出檔案為 d:\dxl\膳食系統\Forms_Dialog_Menu圖片.xlsx。
# 已處理 Forms_NotesForm.dxl，輸出檔案為 d:\dxl\膳食系統\Forms_NotesForm.xlsx。
# 已處理 Forms_台北今日餐點設定.dxl，輸出檔案為 d:\dxl\膳食系統\Forms_台北今日餐點設定.xlsx。
# 已處理 Forms_台北結帳定餐時間設定.dxl，輸出檔案為 d:\dxl\膳食系統\Forms_台北結帳定餐時間設定.xlsx。
# 已處理 Forms_台北餐點設定.dxl，輸出檔案為 d:\dxl\膳食系統\Forms_台北餐點設定.xlsx。
# 已處理 Forms_店家設定.dxl，輸出檔案為 d:\dxl\膳食系統\Forms_店家設定.xlsx。
# 已處理 Forms_店家設定_20210225.dxl，輸出檔案為 d:\dxl\膳食系統\Forms_店家設定_20210225.xlsx。
# 已處理 Forms_新竹今日餐點設定.dxl，輸出檔案為 d:\dxl\膳食系統\Forms_新竹今日餐點設定.xlsx。
# 已處理 Forms_新竹結帳定餐時間設定.dxl，輸出檔案為 d:\dxl\膳食系統\Forms_新竹結帳定餐時間設定.xlsx。
# 已處理 Forms_新竹餐點設定.dxl，輸出檔案為 d:\dxl\膳食系統\Forms_新竹餐點設定.xlsx。
# 已處理 Forms_訂餐紀錄.dxl，輸出檔案為 d:\dxl\膳食系統\Forms_訂餐紀錄.xlsx。
# 已處理 Forms_餐點設定.dxl，輸出檔案為 d:\dxl\膳食系統\Forms_餐點設定.xlsx。
# 已處理 Pages_Cover.dxl，輸出檔案為 d:\dxl\膳食系統\Pages_Cover.xlsx。
# 已處理 Pages_Cover_20230331.dxl，輸出檔案為 d:\dxl\膳食系統\Pages_Cover_20230331.xlsx。
# 已處理 Pages_Cover_20240604.dxl，輸出檔案為 d:\dxl\膳食系統\Pages_Cover_20240604.xlsx。
# 已處理 Pages_Cover_wk.dxl，輸出檔案為 d:\dxl\膳食系統\Pages_Cover_wk.xlsx。
# 已處理 Pages_DBHeader.dxl，輸出檔案為 d:\dxl\膳食系統\Pages_DBHeader.xlsx。
# 已處理 Pages_DBtitle.dxl，輸出檔案為 d:\dxl\膳食系統\Pages_DBtitle.xlsx。
# 已處理 Pages_Help.dxl，輸出檔案為 d:\dxl\膳食系統\Pages_Help.xlsx。
# 已處理 Pages_Menu.dxl，輸出檔案為 d:\dxl\膳食系統\Pages_Menu.xlsx。
# 已處理 Pages_MenuBar.dxl，輸出檔案為 d:\dxl\膳食系統\Pages_MenuBar.xlsx。
# 已處理 Pages_Setup.dxl，輸出檔案為 d:\dxl\膳食系統\Pages_Setup.xlsx。
# 已處理 Pages_Setup_20230331.dxl，輸出檔案為 d:\dxl\膳食系統\Pages_Setup_20230331.xlsx。
# 已處理 Pages_備份：Cover.dxl，輸出檔案為 d:\dxl\膳食系統\Pages_備份：Cover.xlsx。
# 已處理 SubForms_($PMSubForm).dxl，輸出檔案為 d:\dxl\膳食系統\SubForms_($PMSubForm).xlsx。
# 已處理 SubForms_($WFlowApprStatus).dxl，輸出檔案為 d:\dxl\膳食系統\SubForms_($WFlowApprStatus).xlsx。
# 已處理 SubForms_($WFlowApprStatusForWeb).dxl，輸出檔案為 d:\dxl\膳食系統\SubForms_($WFlowApprStatusForWeb).xlsx。
# 已處理 SubForms_($WFlowApprStatusNoPrint).dxl，輸出檔案為 d:\dxl\膳食系統\SubForms_($WFlowApprStatusNoPrint).xlsx。
# 已處理 SubForms_($WFlowButtonsForNotes).dxl，輸出檔案為 d:\dxl\膳食系統\SubForms_($WFlowButtonsForNotes).xlsx。
# 已處理 SubForms_($WFlowButtonsForWeb).dxl，輸出檔案為 d:\dxl\膳食系統\SubForms_($WFlowButtonsForWeb).xlsx。
# 已處理 SubForms_($WFlowControl).dxl，輸出檔案為 d:\dxl\膳食系統\SubForms_($WFlowControl).xlsx。
# 已處理 SubForms_($WFlowFormConfidential).dxl，輸出檔案為 d:\dxl\膳食系統\SubForms_($WFlowFormConfidential).xlsx。
# 已處理 SubForms_($WFlowFormTitle).dxl，輸出檔案為 d:\dxl\膳食系統\SubForms_($WFlowFormTitle).xlsx。
# 已處理 SubForms_($WFSelectBack).dxl，輸出檔案為 d:\dxl\膳食系統\SubForms_($WFSelectBack).xlsx。
# 已處理 SubForms_($WFSelectPO).dxl，輸出檔案為 d:\dxl\膳食系統\SubForms_($WFSelectPO).xlsx。
# 已處理 SubForms_Another Copy Of 餐點訂單.dxl，輸出檔案為 d:\dxl\膳食系統\SubForms_Another Copy Of 餐點訂單.xlsx。
# 已處理 SubForms_Copy Of 餐點訂單.dxl，輸出檔案為 d:\dxl\膳食系統\SubForms_Copy Of 餐點訂單.xlsx。
# 已處理 SubForms_餐點訂單.dxl，輸出檔案為 d:\dxl\膳食系統\SubForms_餐點訂單.xlsx。
# 已處理 SubForms_餐點訂單_20160817.dxl，輸出檔案為 d:\dxl\膳食系統\SubForms_餐點訂單_20160817.xlsx。
# 已處理 SubForms_餐點訂單_20230331.dxl，輸出檔案為 d:\dxl\膳食系統\SubForms_餐點訂單_20230331.xlsx。
# 已處理 SubForms_餐點訂單_Old.dxl，輸出檔案為 d:\dxl\膳食系統\SubForms_餐點訂單_Old.xlsx。
# 已處理 Views_($NotesFlowPath).dxl，輸出檔案為 d:\dxl\膳食系統\Views_($NotesFlowPath).xlsx。
# 已處理 Views_($PMView).dxl，輸出檔案為 d:\dxl\膳食系統\Views_($PMView).xlsx。
# 已處理 Views_($UnSendToStatistic).dxl，輸出檔案為 d:\dxl\膳食系統\Views_($UnSendToStatistic).xlsx。
# 已處理 Views_($WaitForAppr).dxl，輸出檔案為 d:\dxl\膳食系統\Views_($WaitForAppr).xlsx。
# 已處理 Views_($WaitForAppr2).dxl，輸出檔案為 d:\dxl\膳食系統\Views_($WaitForAppr2).xlsx。
# 已處理 Views_($WAudit).dxl，輸出檔案為 d:\dxl\膳食系統\Views_($WAudit).xlsx。
# 已處理 Views_($WAutoST).dxl，輸出檔案為 d:\dxl\膳食系統\Views_($WAutoST).xlsx。
# 已處理 Views_($WebFlowPath).dxl，輸出檔案為 d:\dxl\膳食系統\Views_($WebFlowPath).xlsx。
# 已處理 Views_($WebTrashCan).dxl，輸出檔案為 d:\dxl\膳食系統\Views_($WebTrashCan).xlsx。
# 已處理 Views_($WFlowPath).dxl，輸出檔案為 d:\dxl\膳食系統\Views_($WFlowPath).xlsx。
# 已處理 Views_($WFlowPath_Index).dxl，輸出檔案為 d:\dxl\膳食系統\Views_($WFlowPath_Index).xlsx。
# 已處理 Views_($WFormNameAlias).dxl，輸出檔案為 d:\dxl\膳食系統\Views_($WFormNameAlias).xlsx。
# 已處理 Views_($WVwFieldCKSetup).dxl，輸出檔案為 d:\dxl\膳食系統\Views_($WVwFieldCKSetup).xlsx。
# 已處理 Views_($WVwTmpReader).dxl，輸出檔案為 d:\dxl\膳食系統\Views_($WVwTmpReader).xlsx。
# 已處理 Views_($WVwTmpReader_Prog).dxl，輸出檔案為 d:\dxl\膳食系統\Views_($WVwTmpReader_Prog).xlsx。
# 已處理 Views_($手動稽催).dxl，輸出檔案為 d:\dxl\膳食系統\Views_($手動稽催).xlsx。
# 已處理 Views_A.1依所有訂餐.dxl，輸出檔案為 d:\dxl\膳食系統\Views_A.1依所有訂餐.xlsx。
# 已處理 Views_A.1依所有訂餐todayorder.dxl，輸出檔案為 d:\dxl\膳食系統\Views_A.1依所有訂餐todayorder.xlsx。
# 已處理 Views_A.2依今日所有訂餐.dxl，輸出檔案為 d:\dxl\膳食系統\Views_A.2依今日所有訂餐.xlsx。
# 已處理 Views_B.10依所有訂單by帳號.dxl，輸出檔案為 d:\dxl\膳食系統\Views_B.10依所有訂單by帳號.xlsx。
# 已處理 Views_B.11依所有訂單by匯出csv用.dxl，輸出檔案為 d:\dxl\膳食系統\Views_B.11依所有訂單by匯出csv用.xlsx。
# 已處理 Views_B.12依所有訂單by匯出csv用.dxl，輸出檔案為 d:\dxl\膳食系統\Views_B.12依所有訂單by匯出csv用.xlsx。
# 已處理 Views_B.13依新竹所有訂單by餐點.dxl，輸出檔案為 d:\dxl\膳食系統\Views_B.13依新竹所有訂單by餐點.xlsx。
# 已處理 Views_B.14依所有訂單by匯出csv用2.dxl，輸出檔案為 d:\dxl\膳食系統\Views_B.14依所有訂單by匯出csv用2.xlsx。
# 已處理 Views_B.15依今日台北所有訂餐by餐點.dxl，輸出檔案為 d:\dxl\膳食系統\Views_B.15依今日台北所有訂餐by餐點.xlsx。
# 已處理 Views_B.1依今日新竹所有訂餐by帳號.dxl，輸出檔案為 d:\dxl\膳食系統\Views_B.1依今日新竹所有訂餐by帳號.xlsx。
# 已處理 Views_B.2依今日新竹所有訂餐by餐點.dxl，輸出檔案為 d:\dxl\膳食系統\Views_B.2依今日新竹所有訂餐by餐點.xlsx。
# 已處理 Views_B.3.1依新竹所有訂單by日期.dxl，輸出檔案為 d:\dxl\膳食系統\Views_B.3.1依新竹所有訂單by日期.xlsx。
# 已處理 Views_B.3依新竹所有訂單by日期.dxl，輸出檔案為 d:\dxl\膳食系統\Views_B.3依新竹所有訂單by日期.xlsx。
# 已處理 Views_B.4依新竹所有訂單by帳號.dxl，輸出檔案為 d:\dxl\膳食系統\Views_B.4依新竹所有訂單by帳號.xlsx。
# 已處理 Views_B.5依今日台北所有訂餐by帳號.dxl，輸出檔案為 d:\dxl\膳食系統\Views_B.5依今日台北所有訂餐by帳號.xlsx。
# 已處理 Views_B.6依今日台北所有訂餐by餐點.dxl，輸出檔案為 d:\dxl\膳食系統\Views_B.6依今日台北所有訂餐by餐點.xlsx。
# 已處理 Views_B.7依台北所有訂單by日期.dxl，輸出檔案為 d:\dxl\膳食系統\Views_B.7依台北所有訂單by日期.xlsx。
# 已處理 Views_B.8依台北所有訂單by帳號.dxl，輸出檔案為 d:\dxl\膳食系統\Views_B.8依台北所有訂單by帳號.xlsx。
# 已處理 Views_B.9依今日所有訂餐by餐點.dxl，輸出檔案為 d:\dxl\膳食系統\Views_B.9依今日所有訂餐by餐點.xlsx。
# 已處理 Views_C.1依今日鈊創所有訂餐by帳號.dxl，輸出檔案為 d:\dxl\膳食系統\Views_C.1依今日鈊創所有訂餐by帳號.xlsx。
# 已處理 Views_C.2依今日鈊創所有訂餐by餐點.dxl，輸出檔案為 d:\dxl\膳食系統\Views_C.2依今日鈊創所有訂餐by餐點.xlsx。
# 已處理 Views_C.3依鈊創所有訂單by日期.dxl，輸出檔案為 d:\dxl\膳食系統\Views_C.3依鈊創所有訂單by日期.xlsx。
# 已處理 Views_C.4依鈊創所有訂單by帳號.dxl，輸出檔案為 d:\dxl\膳食系統\Views_C.4依鈊創所有訂單by帳號.xlsx。
# 已處理 Views_C.5依鈊創所有訂單by餐點.dxl，輸出檔案為 d:\dxl\膳食系統\Views_C.5依鈊創所有訂單by餐點.xlsx。
# 已處理 Views_C.6依鈊創所有訂單by匯出csv用.dxl，輸出檔案為 d:\dxl\膳食系統\Views_C.6依鈊創所有訂單by匯出csv用.xlsx。
# 已處理 Views_C.7依所有訂單by匯出csv用.dxl，輸出檔案為 d:\dxl\膳食系統\Views_C.7依所有訂單by匯出csv用.xlsx。
# 已處理 Views_C.8依所有訂單by匯出csv用2.dxl，輸出檔案為 d:\dxl\膳食系統\Views_C.8依所有訂單by匯出csv用2.xlsx。
# 已處理 Views_Copy Of A.1依所有訂餐.dxl，輸出檔案為 d:\dxl\膳食系統\Views_Copy Of A.1依所有訂餐.xlsx。
# 已處理 Views_D.1依今日鈊創所有訂餐by帳號.dxl，輸出檔案為 d:\dxl\膳食系統\Views_D.1依今日鈊創所有訂餐by帳號.xlsx。
# 已處理 Views_D.2依今日鈊創所有訂餐by餐點.dxl，輸出檔案為 d:\dxl\膳食系統\Views_D.2依今日鈊創所有訂餐by餐點.xlsx。
# 已處理 Views_D.3依鈊創所有訂單by日期.dxl，輸出檔案為 d:\dxl\膳食系統\Views_D.3依鈊創所有訂單by日期.xlsx。
# 已處理 Views_D.4依鈊創所有訂單by帳號.dxl，輸出檔案為 d:\dxl\膳食系統\Views_D.4依鈊創所有訂單by帳號.xlsx。
# 已處理 Views_D.5依鈊創所有訂單by餐點.dxl，輸出檔案為 d:\dxl\膳食系統\Views_D.5依鈊創所有訂單by餐點.xlsx。
# 已處理 Views_D.6依鈊創所有訂單by匯出csv用.dxl，輸出檔案為 d:\dxl\膳食系統\Views_D.6依鈊創所有訂單by匯出csv用.xlsx。
# 已處理 Views_D.7依所有訂單by匯出csv用.dxl，輸出檔案為 d:\dxl\膳食系統\Views_D.7依所有訂單by匯出csv用.xlsx。
# 已處理 Views_D.8依所有訂單by匯出csv用2.dxl，輸出檔案為 d:\dxl\膳食系統\Views_D.8依所有訂單by匯出csv用2.xlsx。
# 已處理 Views_E.1依今日慧詠所有訂餐by帳號.dxl，輸出檔案為 d:\dxl\膳食系統\Views_E.1依今日慧詠所有訂餐by帳號.xlsx。
# 已處理 Views_E.2依今日慧詠所有訂餐by餐點.dxl，輸出檔案為 d:\dxl\膳食系統\Views_E.2依今日慧詠所有訂餐by餐點.xlsx。
# 已處理 Views_E.3依慧詠所有訂單by日期.dxl，輸出檔案為 d:\dxl\膳食系統\Views_E.3依慧詠所有訂單by日期.xlsx。
# 已處理 Views_E.4依慧詠所有訂單by帳號.dxl，輸出檔案為 d:\dxl\膳食系統\Views_E.4依慧詠所有訂單by帳號.xlsx。
# 已處理 Views_E.5依慧詠所有訂單by餐點.dxl，輸出檔案為 d:\dxl\膳食系統\Views_E.5依慧詠所有訂單by餐點.xlsx。
# 已處理 Views_E.6依慧詠所有訂單by匯出csv用.dxl，輸出檔案為 d:\dxl\膳食系統\Views_E.6依慧詠所有訂單by匯出csv用.xlsx。
# 已處理 Views_E.7依所有訂單by匯出csv用.dxl，輸出檔案為 d:\dxl\膳食系統\Views_E.7依所有訂單by匯出csv用.xlsx。
# 已處理 Views_E.8依所有訂單by匯出csv用2.dxl，輸出檔案為 d:\dxl\膳食系統\Views_E.8依所有訂單by匯出csv用2.xlsx。
# 已處理 Views_F.1依今日力領所有訂餐by帳號.dxl，輸出檔案為 d:\dxl\膳食系統\Views_F.1依今日力領所有訂餐by帳號.xlsx。
# 已處理 Views_F.2依今日力領所有訂餐by餐點.dxl，輸出檔案為 d:\dxl\膳食系統\Views_F.2依今日力領所有訂餐by餐點.xlsx。
# 已處理 Views_F.3依今日力領所有訂單by日期.dxl，輸出檔案為 d:\dxl\膳食系統\Views_F.3依今日力領所有訂單by日期.xlsx。
# 已處理 Views_F.4依今日力領所有訂單by帳號.dxl，輸出檔案為 d:\dxl\膳食系統\Views_F.4依今日力領所有訂單by帳號.xlsx。
# 已處理 Views_F.5依今日力領所有訂單by餐點.dxl，輸出檔案為 d:\dxl\膳食系統\Views_F.5依今日力領所有訂單by餐點.xlsx。
# 已處理 Views_F.6依今日力領所有訂單by匯出csv用.dxl，輸出檔案為 d:\dxl\膳食系統\Views_F.6依今日力領所有訂單by匯出csv用.xlsx。
# 已處理 Views_F.7依力領所有訂單by匯出csv用.dxl，輸出檔案為 d:\dxl\膳食系統\Views_F.7依力領所有訂單by匯出csv用.xlsx。
# 已處理 Views_F.8依力領所有訂單by匯出csv用2.dxl，輸出檔案為 d:\dxl\膳食系統\Views_F.8依力領所有訂單by匯出csv用2.xlsx。
# 已處理 Views_F.9依力領所有訂單by月.dxl，輸出檔案為 d:\dxl\膳食系統\Views_F.9依力領所有訂單by月.xlsx。
# 已處理 Views_S.1餐點設定byTodaySet.dxl，輸出檔案為 d:\dxl\膳食系統\Views_S.1餐點設定byTodaySet.xlsx。
# 已處理 Views_S.2餐點設定by閱讀.dxl，輸出檔案為 d:\dxl\膳食系統\Views_S.2餐點設定by閱讀.xlsx。
# 已處理 Views_S.3餐點設定.dxl，輸出檔案為 d:\dxl\膳食系統\Views_S.3餐點設定.xlsx。
# 已處理 Views_T.1店名設定.dxl，輸出檔案為 d:\dxl\膳食系統\Views_T.1店名設定.xlsx。
# 已處理 Views_T.2店名設定ForCover.dxl，輸出檔案為 d:\dxl\膳食系統\Views_T.2店名設定ForCover.xlsx。
# 已處理 Views_T.3店名設定For失效.dxl，輸出檔案為 d:\dxl\膳食系統\Views_T.3店名設定For失效.xlsx。
# 已處理 Views_T.4店名設定ForSelect.dxl，輸出檔案為 d:\dxl\膳食系統\Views_T.4店名設定ForSelect.xlsx。
# 已處理 Views_U.1訂餐記錄.dxl，輸出檔案為 d:\dxl\膳食系統\Views_U.1訂餐記錄.xlsx。
# 已處理 Views_U.2訂餐記錄ForSearch.dxl，輸出檔案為 d:\dxl\膳食系統\Views_U.2訂餐記錄ForSearch.xlsx。
# 已處理 Views_Z.1依今日新竹所有訂餐by餐點_包含子公司.dxl，輸出檔案為 d:\dxl\膳食系統\Views_Z.1依今日新竹所有訂餐by餐點_包含子公司.xlsx。
# 已處理 Views_Z.2依今日新竹所有訂餐by餐點_包含子公司.dxl，輸出檔案為 d:\dxl\膳食系統\Views_Z.2依今日新竹所有訂餐by餐點_包含子公司.xlsx。
# 已處理 Views_垃圾桶.dxl，輸出檔案為 d:\dxl\膳食系統\Views_垃圾桶.xlsx。
# 已處理 Views_手動稽催.dxl，輸出檔案為 d:\dxl\膳食系統\Views_手動稽催.xlsx。
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_$自動核准.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_$自動核准_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_$自動稽催.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_$自動稽催_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($CleanDelete).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($CleanDelete)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($CloseWindow).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($CloseWindow)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($CompleteM).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($CompleteM)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($CompleteN).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($CompleteN)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($CompleteN_ADD).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($CompleteN_ADD)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($CompleteW).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($CompleteW)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($Complete_ROS).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($Complete_ROS)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($CopyAttAgent).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($CopyAttAgent)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($DeleteDoc).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($DeleteDoc)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($FieldCheck).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($FieldCheck)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($ISAI_SendEx).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($ISAI_SendEx)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($ISAI_UpdateOutboxState).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($ISAI_UpdateOutboxState)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($Pre_WFlowApprStatus_ADD).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($Pre_WFlowApprStatus_ADD)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($SendMail).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($SendMail)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($UnDelete).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($UnDelete)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($WAgentTmpReaders).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($WAgentTmpReaders)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($WebQueryOpen).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($WebQueryOpen)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($WebQuerySave).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($WebQuerySave)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($WRemoveDoc).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($WRemoveDoc)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($建立文件).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($建立文件)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($手動停止簽核).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($手動停止簽核)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($手動核准).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($手動核准)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($手動稽催).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($手動稽催)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($指定簽核代理人).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($指定簽核代理人)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($檢視簽核狀態).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_($檢視簽核狀態)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(CheckComPay).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(CheckComPay)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(CheckField).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(CheckField)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(CheckTodayFood).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(CheckTodayFood)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(CheckTodayFood_20230406).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(CheckTodayFood_20230406)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(Close).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(Close)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(CreateExtraFood).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(CreateExtraFood)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(Discount).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(Discount)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(ExportDXL).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(ExportDXL)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(F_ViewToCSV).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(F_ViewToCSV)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(GetSerialNo).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(GetSerialNo)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(I_ViewToCSV).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(I_ViewToCSV)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(I_ViewToExcelByDate).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(I_ViewToExcelByDate)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(Merge).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(Merge)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(Merge_Af_ST1).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(Merge_Af_ST1)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(ModifyFood).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(ModifyFood)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(M_ViewToCSV).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(M_ViewToCSV)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(M_ViewToExcelByDate).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(M_ViewToExcelByDate)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(Notify).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(Notify)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(NotifyApplictor).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(NotifyApplictor)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(Open).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(Open)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(PressF9).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(PressF9)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(Q_ViewToCSV).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(Q_ViewToCSV)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(Updatemylunch).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(Updatemylunch)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(ViewToCSV).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(ViewToCSV)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(ViewToCSV20071115).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(ViewToCSV20071115)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(ViewToExcel).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(ViewToExcel)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(ViewToExcelByAccount).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(ViewToExcelByAccount)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(ViewToExcelByDate).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(ViewToExcelByDate)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(備份：I_ViewToCSV).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(備份：I_ViewToCSV)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(備份：M_ViewToCSV).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_(備份：M_ViewToCSV)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_AutoSaveBySelect.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_AutoSaveBySelect_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_ChangeArchive.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_ChangeArchive_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_ImportFromExcel_Food.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_ImportFromExcel_Food_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_lookupCompany.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_lookupCompany_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_lookupEmpNo.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_lookupEmpNo_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_RemoveFlag.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_RemoveFlag_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_UpFlowStep.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_UpFlowStep_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_Utility01. Set Fields.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_Utility01. Set Fields_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_備份：$自動核准.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Agents_備份：$自動核准_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($dlgboxUpFlowStep).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($dlgboxUpFlowStep)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($dlgboxUpFlowStep_mail).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($dlgboxUpFlowStep_mail)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($NameQueryToADD).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($NameQueryToADD)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($NameQueryToCROSS).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($NameQueryToCROSS)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($ODBCProfile).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($ODBCProfile)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($Set Fields).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($Set Fields)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($WFlowForm).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($WFlowForm)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($WFlowSTSetup).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($WFlowSTSetup)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($WNameQueryToADD).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($WNameQueryToADD)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($WNameQueryToCROSS).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($WNameQueryToCROSS)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($WProfile).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($WProfile)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($WSysReaderSetting).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($WSysReaderSetting)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($同名選擇).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($同名選擇)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($指定簽核代理人).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($指定簽核代理人)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($輸入意見).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($輸入意見)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($輸入意見_預覽).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_($輸入意見_預覽)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_(ModifyFoods).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_(ModifyFoods)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_(NotifyApplictor).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_(NotifyApplictor)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_Dialog_Menu圖片.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_Dialog_Menu圖片_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_NotesForm.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_NotesForm_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_台北今日餐點設定.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_台北今日餐點設定_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_台北結帳定餐時間設定.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_台北結帳定餐時間設定_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_台北餐點設定.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_台北餐點設定_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_店家設定.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_店家設定_20210225.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_店家設定_20210225_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_店家設定_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_新竹今日餐點設定.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_新竹今日餐點設定_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_新竹結帳定餐時間設定.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_新竹結帳定餐時間設定_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_新竹餐點設定.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_新竹餐點設定_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_訂餐紀錄.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_訂餐紀錄_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_餐點設定.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Forms_餐點設定_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Pages_Cover.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Pages_Cover_20230331.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Pages_Cover_20230331_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Pages_Cover_20240604.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Pages_Cover_20240604_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Pages_Cover_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Pages_Cover_wk.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Pages_Cover_wk_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Pages_DBHeader.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Pages_DBHeader_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Pages_DBtitle.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Pages_DBtitle_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Pages_Help.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Pages_Help_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Pages_Menu.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Pages_MenuBar.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Pages_MenuBar_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Pages_Menu_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Pages_Setup.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Pages_Setup_20230331.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Pages_Setup_20230331_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Pages_Setup_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Pages_備份：Cover.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Pages_備份：Cover_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_($PMSubForm).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_($PMSubForm)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_($WFlowApprStatus).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_($WFlowApprStatus)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_($WFlowApprStatusForWeb).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_($WFlowApprStatusForWeb)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_($WFlowApprStatusNoPrint).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_($WFlowApprStatusNoPrint)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_($WFlowButtonsForNotes).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_($WFlowButtonsForNotes)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_($WFlowButtonsForWeb).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_($WFlowButtonsForWeb)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_($WFlowControl).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_($WFlowControl)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_($WFlowFormConfidential).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_($WFlowFormConfidential)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_($WFlowFormTitle).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_($WFlowFormTitle)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_($WFSelectBack).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_($WFSelectBack)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_($WFSelectPO).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_($WFSelectPO)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_Another Copy Of 餐點訂單.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_Another Copy Of 餐點訂單_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_Copy Of 餐點訂單.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_Copy Of 餐點訂單_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_餐點訂單.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_餐點訂單_20160817.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_餐點訂單_20160817_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_餐點訂單_20230331.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_餐點訂單_20230331_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_餐點訂單_Old.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_餐點訂單_Old_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_SubForms_餐點訂單_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($NotesFlowPath).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($NotesFlowPath)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($PMView).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($PMView)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($UnSendToStatistic).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($UnSendToStatistic)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($WaitForAppr).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($WaitForAppr)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($WaitForAppr2).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($WaitForAppr2)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($WAudit).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($WAudit)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($WAutoST).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($WAutoST)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($WebFlowPath).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($WebFlowPath)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($WebTrashCan).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($WebTrashCan)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($WFlowPath).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($WFlowPath)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($WFlowPath_Index).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($WFlowPath_Index)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($WFormNameAlias).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($WFormNameAlias)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($WVwFieldCKSetup).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($WVwFieldCKSetup)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($WVwTmpReader).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($WVwTmpReader)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($WVwTmpReader_Prog).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($WVwTmpReader_Prog)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($手動稽催).dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_($手動稽催)_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_A.1依所有訂餐.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_A.1依所有訂餐todayorder.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_A.1依所有訂餐todayorder_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_A.1依所有訂餐_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_A.2依今日所有訂餐.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_A.2依今日所有訂餐_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.10依所有訂單by帳號.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.10依所有訂單by帳號_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.11依所有訂單by匯出csv用.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.11依所有訂單by匯出csv用_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.12依所有訂單by匯出csv用.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.12依所有訂單by匯出csv用_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.13依新竹所有訂單by餐點.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.13依新竹所有訂單by餐點_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.14依所有訂單by匯出csv用2.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.14依所有訂單by匯出csv用2_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.15依今日台北所有訂餐by餐點.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.15依今日台北所有訂餐by餐點_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.1依今日新竹所有訂餐by帳號.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.1依今日新竹所有訂餐by帳號_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.2依今日新竹所有訂餐by餐點.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.2依今日新竹所有訂餐by餐點_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.3.1依新竹所有訂單by日期.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.3.1依新竹所有訂單by日期_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.3依新竹所有訂單by日期.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.3依新竹所有訂單by日期_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.4依新竹所有訂單by帳號.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.4依新竹所有訂單by帳號_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.5依今日台北所有訂餐by帳號.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.5依今日台北所有訂餐by帳號_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.6依今日台北所有訂餐by餐點.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.6依今日台北所有訂餐by餐點_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.7依台北所有訂單by日期.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.7依台北所有訂單by日期_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.8依台北所有訂單by帳號.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.8依台北所有訂單by帳號_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.9依今日所有訂餐by餐點.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_B.9依今日所有訂餐by餐點_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_C.1依今日鈊創所有訂餐by帳號.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_C.1依今日鈊創所有訂餐by帳號_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_C.2依今日鈊創所有訂餐by餐點.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_C.2依今日鈊創所有訂餐by餐點_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_C.3依鈊創所有訂單by日期.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_C.3依鈊創所有訂單by日期_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_C.4依鈊創所有訂單by帳號.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_C.4依鈊創所有訂單by帳號_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_C.5依鈊創所有訂單by餐點.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_C.5依鈊創所有訂單by餐點_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_C.6依鈊創所有訂單by匯出csv用.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_C.6依鈊創所有訂單by匯出csv用_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_C.7依所有訂單by匯出csv用.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_C.7依所有訂單by匯出csv用_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_C.8依所有訂單by匯出csv用2.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_C.8依所有訂單by匯出csv用2_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_Copy Of A.1依所有訂餐.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_Copy Of A.1依所有訂餐_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_D.1依今日鈊創所有訂餐by帳號.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_D.1依今日鈊創所有訂餐by帳號_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_D.2依今日鈊創所有訂餐by餐點.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_D.2依今日鈊創所有訂餐by餐點_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_D.3依鈊創所有訂單by日期.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_D.3依鈊創所有訂單by日期_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_D.4依鈊創所有訂單by帳號.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_D.4依鈊創所有訂單by帳號_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_D.5依鈊創所有訂單by餐點.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_D.5依鈊創所有訂單by餐點_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_D.6依鈊創所有訂單by匯出csv用.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_D.6依鈊創所有訂單by匯出csv用_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_D.7依所有訂單by匯出csv用.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_D.7依所有訂單by匯出csv用_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_D.8依所有訂單by匯出csv用2.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_D.8依所有訂單by匯出csv用2_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_E.1依今日慧詠所有訂餐by帳號.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_E.1依今日慧詠所有訂餐by帳號_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_E.2依今日慧詠所有訂餐by餐點.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_E.2依今日慧詠所有訂餐by餐點_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_E.3依慧詠所有訂單by日期.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_E.3依慧詠所有訂單by日期_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_E.4依慧詠所有訂單by帳號.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_E.4依慧詠所有訂單by帳號_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_E.5依慧詠所有訂單by餐點.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_E.5依慧詠所有訂單by餐點_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_E.6依慧詠所有訂單by匯出csv用.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_E.6依慧詠所有訂單by匯出csv用_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_E.7依所有訂單by匯出csv用.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_E.7依所有訂單by匯出csv用_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_E.8依所有訂單by匯出csv用2.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_E.8依所有訂單by匯出csv用2_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_F.1依今日力領所有訂餐by帳號.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_F.1依今日力領所有訂餐by帳號_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_F.2依今日力領所有訂餐by餐點.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_F.2依今日力領所有訂餐by餐點_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_F.3依今日力領所有訂單by日期.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_F.3依今日力領所有訂單by日期_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_F.4依今日力領所有訂單by帳號.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_F.4依今日力領所有訂單by帳號_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_F.5依今日力領所有訂單by餐點.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_F.5依今日力領所有訂單by餐點_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_F.6依今日力領所有訂單by匯出csv用.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_F.6依今日力領所有訂單by匯出csv用_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_F.7依力領所有訂單by匯出csv用.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_F.7依力領所有訂單by匯出csv用_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_F.8依力領所有訂單by匯出csv用2.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_F.8依力領所有訂單by匯出csv用2_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_F.9依力領所有訂單by月.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_F.9依力領所有訂單by月_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_S.1餐點設定byTodaySet.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_S.1餐點設定byTodaySet_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_S.2餐點設定by閱讀.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_S.2餐點設定by閱讀_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_S.3餐點設定.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_S.3餐點設定_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_T.1店名設定.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_T.1店名設定_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_T.2店名設定ForCover.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_T.2店名設定ForCover_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_T.3店名設定For失效.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_T.3店名設定For失效_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_T.4店名設定ForSelect.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_T.4店名設定ForSelect_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_U.1訂餐記錄.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_U.1訂餐記錄_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_U.2訂餐記錄ForSearch.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_U.2訂餐記錄ForSearch_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_Z.1依今日新竹所有訂餐by餐點_包含子公司.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_Z.1依今日新竹所有訂餐by餐點_包含子公司_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_Z.2依今日新竹所有訂餐by餐點_包含子公司.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_Z.2依今日新竹所有訂餐by餐點_包含子公司_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_垃圾桶.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_垃圾桶_process.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_手動稽催.dxl
# 已刪除文件: d:\dxl\膳食系統\fixed_Views_手動稽催_process.dxl
# 所有 DXL 檔案已處理完成。

# %%
# Out:
# Requirement already satisfied: pandas in c:\users\james_liao\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\james_liao\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\james_liao\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\james_liao\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\james_liao\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\james_liao\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
